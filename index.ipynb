# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import re
import numpy as np

# %%
html_page = requests.get('https://www.residentadvisor.net/events')
soup = bs(html_page.content, 'html.parser')

# %%
url = 'https://www.residentadvisor.net/events'

# %%
def scrape_events(events_page_url):
    soup = bs(requests.get(events_page_url).content, 'html.parser')
    event_container = soup.find('div', class_="content clearfix")
    dates = [date.text.strip()[:-6] for date in event_container.findAll('time')]
    names = [name.find('a').text.strip() for name in event_container.findAll('h1'
                                            ,class_='event-title')]
    venues = [venue.find('span').text.strip()[3:] for venue 
                  in event_container.findAll('h1', class_='event-title')]
    attendees = [attendee.find('span').text.strip() for attendee 
                  in event_container.findAll('p', class_='attending')]
    df=pd.DataFrame([names, venues, dates, attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events(url)
# Out:
#                                            Event_Name  \
# 0     Clinic with Sebastian Mullaert (Circle of Live)
# 1          CCVO Thursdays with Kerim Bey & Joe Dismal
# 2       Postponed - Damian Lazarus (Crosstown Rebels)
# 3               [CANCELLED] DJ Koze & Floating Points
# 4                                           Cancelled
# 5   Desert Dream feat. Walker & Royce, Will Clarke...
# 6   Canceled - Om Unit, The Librarian, J:Kenzo by ...
# 7                          [POSTPONED] Coachella 2020
# 8   DUBLAB x Doom Trip present: The Doom Mix IV Re...
# 9                           Rich Medina presents Home
# 10         Family Reunion presents: Golden Vinyl Club
# 11                                SD Union with Break
# 12                                  Lucidity Festival
# 13              [POSTPONED] Monolink with Viken Arman
# 14                                  [POSTPONED] SAMA'
# 15  Incognito presents Freddy K (LA Debut) - Key V...
# 16                         [POSTPONED] Coachella 2020
# 17                               Preceding Thoughts 4
# 18  Essence of Trance 25 Years of RAM with Ciaran ...
# 19     Planet Disco: The Sponges + Take Me To Tequila
# 20                                  Lucidity Festival
# 21  The Polish Ambassador & Friends with The Human...
# 22  [CANCELLED] Official Movement Pre-Party – Cogn...
# 23                             [POSTPONED] Guy Gerber
# 24                         [POSTPONED] Coachella 2020
# 25                                  Lucidity Festival
# 26  Framework x Goldenvoice x Cuttin Headz present...
# 27                                         Disclosure
#
#                                                 Venue  Event_Date  \
# 0                        The Sayers Club, Los Angeles  2020-04-08
# 1                       Underground SF, San Francisco  2020-04-09
# 2                         Public Works, San Francisco  2020-04-09
# 3                          1015 Folsom, San Francisco  2020-04-10
# 4                       F8 1192 Folsom, San Francisco  2020-04-10
# 5                                         Equl Estate  2020-04-10
# 6                         Public Works, San Francisco  2020-04-10
# 7                                    Empire Polo Club  2020-04-10
# 8                      TBA - Downtown LA, Los Angeles  2020-04-10
# 9                               Resident, Los Angeles  2020-04-10
# 10                            251 Club, San Francisco  2020-04-10
# 11                                    Spin, San Diego  2020-04-10
# 12                   Live Oak Campground, Los Angeles  2020-04-10
# 13                          The Midway, San Francisco  2020-04-10
# 14                             Halcyon, San Francisco  2020-04-10
# 15                     TBA - Los Angeles, Los Angeles  2020-04-11
# 16                                   Empire Polo Club  2020-04-11
# 17                     TBA - Downtown LA, Los Angeles  2020-04-11
# 18                      Avalon Hollywood, Los Angeles  2020-04-11
# 19                   The Valencia Room, San Francisco  2020-04-11
# 20                   Live Oak Campground, Los Angeles  2020-04-11
# 21                                       The Fillmore  2020-04-11
# 22                                  TBA - Los Angeles  2020-04-11
# 23                             Halcyon, San Francisco  2020-04-11
# 24                                   Empire Polo Club  2020-04-12
# 25                   Live Oak Campground, Los Angeles  2020-04-12
# 26                        El Rey Theatre, Los Angeles  2020-04-14
# 27  Event Center at San Jose State University, San...  2020-04-14
#
#    Number_of_Attendees
# 0                    7
# 1                    1
# 2                   22
# 3                   37
# 4                   22
# 5                    2
# 6                    2
# 7                   23
# 8                    2
# 9                    1
# 10                   1
# 11                  19
# 12                  23
# 13                   4
# 14                   2
# 15                   1
# 16                   9
# 17                  23
# 18                  13
# 19                   6
# 20                None
# 21                None
# 22                None
# 23                None
# 24                None
# 25                None
# 26                None
# 27                None

# %%
def scrape_event2(events_page_url):
    soup = bs(requests.get(events_page_url).content, 'html.parser')
    event_container = soup.find('ul', id="items").findAll('article')
    dates = []
    names = []
    venues = []
    attendees = []
    for index in range(len(event_container)):
        date = event_container[index].find('time').text.strip()[:-6]
        dates.append(date)
        name = event_container[index].find('h1',
                    class_='event-title').find('a').text.strip()
        names.append(name)
        venue = event_container[index].find('h1',
                    class_='event-title').find('span').text.strip()[3:]
        venues.append(venue)
        try: attendee = event_container[index].find('p', 
                    class_='attending').find('span').text
        except: 
            attendee = 0
        attendees.append(attendee)
    df = pd.DataFrame([names, venues, dates, attendees]).transpose()
    df.columns = ['Event_Name','Venue', 'Event_Date', 'Number_of_Attendees']
    return df

# %%
scrape_event2(url)
# Out:
#                                            Event_Name  \
# 0     Clinic with Sebastian Mullaert (Circle of Live)
# 1          CCVO Thursdays with Kerim Bey & Joe Dismal
# 15                  19
# 16                  23
# 17                   4
# 18                   2
# 19                   1
# 20                   0
# 21                   0
# 22                   9
# 23                   0
# 24                  23
# 25                   0
# 26                  13
# 27                   6

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    soup = bs(requests.get(url).content, 'html.parser')
    url_container = soup.find('li', id = 'liNext2')
    next_page_ref = url_container.find('a').attrs['href']
    next_page_url = "https://www.residentadvisor.net" + next_page_ref
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events"
while total_rows <= 150:
    df = scrape_event2(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
df = pd.concat(dfs)
df = df.iloc[:150]
print(len(df))
df.head()
#Your code here
# Out:
# 150
#                                         Event_Name  \
# 0  Clinic with Sebastian Mullaert (Circle of Live)
# 1       CCVO Thursdays with Kerim Bey & Joe Dismal
# 2    Postponed - Damian Lazarus (Crosstown Rebels)
# 3            [CANCELLED] DJ Koze & Floating Points
# 4                                        Cancelled
#
#                            Venue  Event_Date Number_of_Attendees
# 0   The Sayers Club, Los Angeles  2020-04-08                   7
# 1  Underground SF, San Francisco  2020-04-09                   1
# 2    Public Works, San Francisco  2020-04-09                  22
# 3     1015 Folsom, San Francisco  2020-04-10                  37
# 4  F8 1192 Folsom, San Francisco  2020-04-10                  22

# %%
df
# Out:
#                                            Event_Name  \
# 0     Clinic with Sebastian Mullaert (Circle of Live)
# 1          CCVO Thursdays with Kerim Bey & Joe Dismal
# 2       Postponed - Damian Lazarus (Crosstown Rebels)
# 3               [CANCELLED] DJ Koze & Floating Points
# 4                                           Cancelled
# ..                                                ...
# 6                    Pink Block – Pride Saturday 2020
# 0   Ayli 10 Year Kickoff: Joy Orbison B2B Ben UFO ...
# 1                       [RESCHEDULED] Atish All Night
# 0                           Chemical Surf - U.S. Tour
# 0                                 Sunset Campout 2020
#
#                                 Venue  Event_Date Number_of_Attendees
# 0        The Sayers Club, Los Angeles  2020-04-08                   7
# 1       Underground SF, San Francisco  2020-04-09                   1
# 2         Public Works, San Francisco  2020-04-09                  22
# 3          1015 Folsom, San Francisco  2020-04-10                  37
# 4       F8 1192 Folsom, San Francisco  2020-04-10                  22
# ..                                ...         ...                 ...
# 6   The Great Northern, San Francisco  2020-06-28                   1
# 0         Public Works, San Francisco  2020-07-10                  12
# 1      TBA - Los Angeles, Los Angeles  2020-07-11                 236
# 0       Avalon Hollywood, Los Angeles  2020-07-17                   2
# 0          Belden Town, San Francisco  2020-07-24                 292
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
